# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
data=pd.read_csv('GDP_Country.csv')
data.head()
# Out:
#            Country                               Region  Population  Area_sqm  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997    647500
# 1         Albania   EASTERN EUROPE                          3581655     28748
# 2         Algeria   NORTHERN AFRICA                        32930091   2381740
# 3  American Samoa   OCEANIA                                   57794       199
# 4         Andorra   WESTERN EUROPE                            71201       468
#
#    Pop_Density_per sqm  Coastline (coast/area ratio)  Net migration  \
# 0                 48.0                          0.00          23.06
# 1                124.6                          1.26          -4.93
# 2                 13.8                          0.04          -0.39
# 3                290.4                         58.29         -20.71
# 4                152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                              163.07               700.0          36.0
# 1                               21.52              4500.0          86.5
# 2                               31.00              6000.0          70.0
# 3                                9.27              8000.0          97.0
# 4                                4.05             19000.0         100.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                3.2       12.13       0.22      87.65      1.0      46.60
# 1               71.2       21.09       4.42      74.49      3.0      15.11
# 2               78.1        3.22       0.25      96.53      1.0      17.14
# 3              259.5       10.00      15.00      75.00      2.0      22.46
# 4              497.2        2.22       0.00      97.78      3.0       8.71
#
#    Deathrate  Agriculture  Industry  Service
# 0      20.34        0.380     0.240    0.380
# 1       5.22        0.232     0.188    0.579
# 2       4.61        0.101     0.600    0.298
# 3       3.27          NaN       NaN      NaN
# 4       6.25          NaN       NaN      NaN

# %%
data.set_index(['Country','Region'],inplace=True)
data.head()
# Out:
#                                                      Population  Area_sqm  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                   31056997    647500
# Albania         EASTERN EUROPE                          3581655     28748
# Algeria         NORTHERN AFRICA                        32930091   2381740
# American Samoa  OCEANIA                                   57794       199
# Andorra         WESTERN EUROPE                            71201       468
#
#                                                      Pop_Density_per sqm  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                48.0
# Albania         EASTERN EUROPE                                     124.6
# Algeria         NORTHERN AFRICA                                     13.8
# American Samoa  OCEANIA                                            290.4
# Andorra         WESTERN EUROPE                                     152.1
#
#                                                      Coastline (coast/area ratio)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                         0.00
# Albania         EASTERN EUROPE                                               1.26
# Algeria         NORTHERN AFRICA                                              0.04
# American Samoa  OCEANIA                                                     58.29
# Andorra         WESTERN EUROPE                                               0.00
#
#                                                      Net migration  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                         23.06
# Albania         EASTERN EUROPE                               -4.93
# Algeria         NORTHERN AFRICA                              -0.39
# American Samoa  OCEANIA                                     -20.71
# Andorra         WESTERN EUROPE                                6.60
#
#                                                      Infant mortality (per 1000 births)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                             163.07
# Albania         EASTERN EUROPE                                                    21.52
# Algeria         NORTHERN AFRICA                                                   31.00
# American Samoa  OCEANIA                                                            9.27
# Andorra         WESTERN EUROPE                                                     4.05
#
#                                                      GDP ($ per capita)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                              700.0
# Albania         EASTERN EUROPE                                   4500.0
# Algeria         NORTHERN AFRICA                                  6000.0
# American Samoa  OCEANIA                                          8000.0
# Andorra         WESTERN EUROPE                                  19000.0
#
#                                                      Literacy (%)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                         36.0
# Albania         EASTERN EUROPE                               86.5
# Algeria         NORTHERN AFRICA                              70.0
# American Samoa  OCEANIA                                      97.0
# Andorra         WESTERN EUROPE                              100.0
#
#                                                      Phones (per 1000)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                               3.2
# Albania         EASTERN EUROPE                                    71.2
# Algeria         NORTHERN AFRICA                                   78.1
# American Samoa  OCEANIA                                          259.5
# Andorra         WESTERN EUROPE                                   497.2
#
#                                                      Arable (%)  Crops (%)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                      12.13       0.22
# Albania         EASTERN EUROPE                            21.09       4.42
# Algeria         NORTHERN AFRICA                            3.22       0.25
# American Samoa  OCEANIA                                   10.00      15.00
# Andorra         WESTERN EUROPE                             2.22       0.00
#
#                                                      Other (%)  Climate  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                     87.65      1.0
# Albania         EASTERN EUROPE                           74.49      3.0
# Algeria         NORTHERN AFRICA                          96.53      1.0
# American Samoa  OCEANIA                                  75.00      2.0
# Andorra         WESTERN EUROPE                           97.78      3.0
#
#                                                      Birthrate  Deathrate  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                     46.60      20.34
# Albania         EASTERN EUROPE                           15.11       5.22
# Algeria         NORTHERN AFRICA                          17.14       4.61
# American Samoa  OCEANIA                                  22.46       3.27
# Andorra         WESTERN EUROPE                            8.71       6.25
#
#                                                      Agriculture  Industry  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                       0.380     0.240
# Albania         EASTERN EUROPE                             0.232     0.188
# Algeria         NORTHERN AFRICA                            0.101     0.600
# American Samoa  OCEANIA                                      NaN       NaN
# Andorra         WESTERN EUROPE                               NaN       NaN
#
#                                                      Service
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                   0.380
# Albania         EASTERN EUROPE                         0.579
# Algeria         NORTHERN AFRICA                        0.298
# American Samoa  OCEANIA                                  NaN
# Andorra         WESTERN EUROPE                           NaN

# %%
data.isnull().sum()
# Out:
# Population                             0
# Area_sqm                               0
# Pop_Density_per sqm                    0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
fill_mod=KNNImputer(n_neighbors=3)
data_fill=fill_mod.fit_transform(data)
data_fill=pd.DataFrame(data_fill)

data_fill.columns=data.columns

data_fill.index=data.index

# %%
data_fill.head()
# Out:
#                                                      Population   Area_sqm  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                 31056997.0   647500.0
# Albania         EASTERN EUROPE                        3581655.0    28748.0
# Algeria         NORTHERN AFRICA                      32930091.0  2381740.0
# American Samoa  OCEANIA                                 57794.0      199.0
# Andorra         WESTERN EUROPE                          71201.0      468.0
#
#                                                      Pop_Density_per sqm  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                48.0
# Albania         EASTERN EUROPE                                     124.6
# Algeria         NORTHERN AFRICA                                     13.8
# American Samoa  OCEANIA                                            290.4
# Andorra         WESTERN EUROPE                                     152.1
#
#                                                      Coastline (coast/area ratio)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                         0.00
# Albania         EASTERN EUROPE                                               1.26
# Algeria         NORTHERN AFRICA                                              0.04
# American Samoa  OCEANIA                                                     58.29
# Andorra         WESTERN EUROPE                                               0.00
#
#                                                      Net migration  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                         23.06
# Albania         EASTERN EUROPE                               -4.93
# Algeria         NORTHERN AFRICA                              -0.39
# American Samoa  OCEANIA                                     -20.71
# Andorra         WESTERN EUROPE                                6.60
#
#                                                      Infant mortality (per 1000 births)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                                             163.07
# Albania         EASTERN EUROPE                                                    21.52
# Algeria         NORTHERN AFRICA                                                   31.00
# American Samoa  OCEANIA                                                            9.27
# Andorra         WESTERN EUROPE                                                     4.05
#
#                                                      GDP ($ per capita)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                              700.0
# Albania         EASTERN EUROPE                                   4500.0
# Algeria         NORTHERN AFRICA                                  6000.0
# American Samoa  OCEANIA                                          8000.0
# Andorra         WESTERN EUROPE                                  19000.0
#
#                                                      Literacy (%)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                         36.0
# Albania         EASTERN EUROPE                               86.5
# Algeria         NORTHERN AFRICA                              70.0
# American Samoa  OCEANIA                                      97.0
# Andorra         WESTERN EUROPE                              100.0
#
#                                                      Phones (per 1000)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                               3.2
# Albania         EASTERN EUROPE                                    71.2
# Algeria         NORTHERN AFRICA                                   78.1
# American Samoa  OCEANIA                                          259.5
# Andorra         WESTERN EUROPE                                   497.2
#
#                                                      Arable (%)  Crops (%)  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                      12.13       0.22
# Albania         EASTERN EUROPE                            21.09       4.42
# Algeria         NORTHERN AFRICA                            3.22       0.25
# American Samoa  OCEANIA                                   10.00      15.00
# Andorra         WESTERN EUROPE                             2.22       0.00
#
#                                                      Other (%)  Climate  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                     87.65      1.0
# Albania         EASTERN EUROPE                           74.49      3.0
# Algeria         NORTHERN AFRICA                          96.53      1.0
# American Samoa  OCEANIA                                  75.00      2.0
# Andorra         WESTERN EUROPE                           97.78      3.0
#
#                                                      Birthrate  Deathrate  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                     46.60      20.34
# Albania         EASTERN EUROPE                           15.11       5.22
# Algeria         NORTHERN AFRICA                          17.14       4.61
# American Samoa  OCEANIA                                  22.46       3.27
# Andorra         WESTERN EUROPE                            8.71       6.25
#
#                                                      Agriculture  Industry  \
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                    0.380000  0.240000
# Albania         EASTERN EUROPE                          0.232000  0.188000
# Algeria         NORTHERN AFRICA                         0.101000  0.600000
# American Samoa  OCEANIA                                 0.177333  0.232333
# Andorra         WESTERN EUROPE                          0.026000  0.150000
#
#                                                       Service
# Country         Region
# Afghanistan     ASIA (EX. NEAR EAST)                 0.380000
# Albania         EASTERN EUROPE                       0.579000
# Algeria         NORTHERN AFRICA                      0.298000
# American Samoa  OCEANIA                              0.590667
# Andorra         WESTERN EUROPE                       0.824333

# %%
out=data_fill['GDP ($ per capita)']
inp=data_fill.drop('GDP ($ per capita)',axis=1)
inp_c=sm.add_constant(inp)
result=sm.OLS(out,inp_c).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     GDP ($ per capita)   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                     38.33
# Date:                Mon, 14 Sep 2020   Prob (F-statistic):           9.91e-55
# Time:                        12:47:51   Log-Likelihood:                -2252.4
# No. Observations:                 227   AIC:                             4541.
# Df Residuals:                     209   BIC:                             4602.
# Df Model:                          17
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                               6.866e+06   4.38e+06      1.568      0.118   -1.76e+06    1.55e+07
# Population                         -2.141e-06   3.49e-06     -0.614      0.540   -9.02e-06    4.73e-06
# Area_sqm                            6.223e-05      0.000      0.271      0.786      -0.000       0.001
# Pop_Density_per sqm                   -0.2643      0.231     -1.143      0.255      -0.720       0.192
# Coastline (coast/area ratio)          -1.2588      5.508     -0.229      0.819     -12.117       9.599
# Net migration                        408.4657     78.229      5.221      0.000     254.246     562.685
# Infant mortality (per 1000 births)   -41.5199     28.186     -1.473      0.142     -97.086      14.046
# Literacy (%)                          -5.4163     30.400     -0.178      0.859     -65.346      54.514
# Phones (per 1000)                     30.6874      2.651     11.575      0.000      25.461      35.914
# Arable (%)                         -6.857e+04   4.38e+04     -1.567      0.119   -1.55e+05    1.77e+04
# Crops (%)                          -6.857e+04   4.38e+04     -1.567      0.119   -1.55e+05    1.77e+04
# Other (%)                          -6.855e+04   4.38e+04     -1.566      0.119   -1.55e+05    1.77e+04
# Climate                             -150.4137    647.173     -0.232      0.816   -1426.238    1125.411
# Birthrate                            -56.2401     77.103     -0.729      0.467    -208.240      95.760
# Deathrate                            186.5139    109.269      1.707      0.089     -28.898     401.925
# Agriculture                        -8331.3607   1.49e+04     -0.561      0.576   -3.76e+04     2.1e+04
# Industry                           -1660.1731   1.45e+04     -0.114      0.909   -3.03e+04     2.7e+04
# Service                            -6957.7759   1.46e+04     -0.477      0.634   -3.57e+04    2.18e+04
# ==============================================================================
# Omnibus:                       80.157   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              647.363
# Skew:                           1.123   Prob(JB):                    2.67e-141
# Kurtosis:                      10.962   Cond. No.                     1.55e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
vf=[vif(inp.values,i) for i in range(inp.shape[1])]
pd.DataFrame(vf,index=inp.columns,columns=['vif'])
# Out:
#                                             vif
# Population                             1.530914
# Area_sqm                               1.599127
# Pop_Density_per sqm                    1.326822
# Coastline (coast/area ratio)           1.472364
# Net migration                          1.253557
# Infant mortality (per 1000 births)    16.583538
# Literacy (%)                          57.904914
# Phones (per 1000)                      6.436494
# Arable (%)                            69.694365
# Crops (%)                             19.791211
# Other (%)                           1294.273280
# Climate                               18.286506
# Birthrate                             30.249978
# Deathrate                             11.200660
# Agriculture                           79.687371
# Industry                             170.954685
# Service                              656.101432
